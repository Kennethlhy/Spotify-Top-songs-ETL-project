# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '27ffb65da3ba4f96acf449e240d9636b', client_secret= 'cf227e06b8da47e18f6256a4aca2927f')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'
playlist_link = 'https://open.spotify.com/playlist/37i9dQZF1DXdGUQjVlqY2Q'  #podcast ranking

# %%
playlist_URI = playlist_link.split("/")[4]

# %%
playlist_link.split("/")
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '37i9dQZF1DXdGUQjVlqY2Q']

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
print(data)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXdGUQjVlqY2Q/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2023-11-23T16:00:00Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'}, 'href': 'https://api.spotify.com/v1/users/', 'id': '', 'type': 'user', 'uri': 'spotify:user:'}, 'is_local': False, 'primary_color': None, 'track': {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EXI1ieJe2VDbvNsKOaNQL'}, 'href': 'https://api.spotify.com/v1/artists/4EXI1ieJe2VDbvNsKOaNQL', 'id': '4EXI1ieJe2VDbvNsKOaNQL', 'name': 'Jay Fung', 'type': 'artist', 'uri': 'spotify:artist:4EXI1ieJe2VDbvNsKOaNQL'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', '
# ...

# %%
data['items']
# Out:
# [{'added_at': '2023-11-23T16:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EXI1ieJe2VDbvNsKOaNQL'},
#       'href': 'https://api.spotify.com/v1/artists/4EXI1ieJe2VDbvNsKOaNQL',
#       'id': '4EXI1ieJe2VDbvNsKOaNQL',
#       'name': 'Jay Fung',
#       'type': 'artist',
#       'uri': 'spotify:artist:4EXI1ieJe2VDbvNsKOaNQL'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EXI1ieJe2VDbvNsKOaNQL'},
#     'href': 'https://api.spotify.com/v1/artists/4EXI1ieJe2VDbvNsKOaNQL',
#     'id': '4EXI1ieJe2VDbvNsKOaNQL',
#     'name': 'Jay Fung',
#     'type': 'artist',
#     'uri': 'spotify:artist:4EXI1ieJe2VDbvNsKOaNQL'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
# ...

# %%
list = []
for i in range(len(data)):
    list.append(data['items'][i]['track'])
    
print(list)
# Out:
# [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EXI1ieJe2VDbvNsKOaNQL'}, 'href': 'https://api.spotify.com/v1/artists/4EXI1ieJe2VDbvNsKOaNQL', 'id': '4EXI1ieJe2VDbvNsKOaNQL', 'name': 'Jay Fung', 'type': 'artist', 'uri': 'spotify:artist:4EXI1ieJe2VDbvNsKOaNQL'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'D
# ...

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id': album_id, 'album_name':album_name, 'album_release_date':album_release_date, 'album_total_tracks':album_total_tracks, 'album_url':album_url}
    album_list.append(album_element)
    
print(album_element)
# Out:
# {'album_id': '27rpPfkINIq6TIvVb2aHba', 'album_name': '終於出歌', 'album_release_date': '2023-10-10', 'album_total_tracks': 1, 'album_url': 'https://open.spotify.com/album/27rpPfkINIq6TIvVb2aHba'}

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '4EXI1ieJe2VDbvNsKOaNQL'

# %%
data['items'][3]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qW9Pi35NXnu7Q8KWyVYe6'},
#   'href': 'https://api.spotify.com/v1/artists/1qW9Pi35NXnu7Q8KWyVYe6',
#   'id': '1qW9Pi35NXnu7Q8KWyVYe6',
#   'name': '陳卓賢 Ian',
#   'type': 'artist',
#   'uri': 'spotify:artist:1qW9Pi35NXnu7Q8KWyVYe6'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2023-11-23T16:00:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4EXI1ieJe2VDbvNsKOaNQL'},
#      'href': 'https://api.spotify.com/v1/artists/4EXI1ieJe2VDbvNsKOaNQL',
#      'id': '4EXI1ieJe2VDbvNsKOaNQL',
#      'name': 'Jay Fung',
#      'type': 'artist',
#      'uri': 'spotify:artist:4EXI1ieJe2VDbvNsKOaNQL'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
# ...

# %%
artists_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 artists_list
#
# NameError: name 'artists_list' is not defined

# %%
artists_list = []

for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for datapoint in value['artists']: 
                artists_id = datapoint['id']
                artists_name = datapoint['name']
                artists_uri = datapoint['uri']
            artists_element = {'artists_id': artists_id, 'artists_name': artists_name, 'artists_uri': artists_uri }
            artists_list.append(artists_element)

print(artists_list)
# Out:
# [{'artists_id': '4EXI1ieJe2VDbvNsKOaNQL', 'artists_name': 'Jay Fung', 'artists_uri': 'spotify:artist:4EXI1ieJe2VDbvNsKOaNQL'}, {'artists_id': '0UtXMxHMXhwQUI6G6TFDt1', 'artists_name': 'Gin Lee', 'artists_uri': 'spotify:artist:0UtXMxHMXhwQUI6G6TFDt1'}, {'artists_id': '5tRk0bqMQubKAVowp35XtC', 'artists_name': 'MC 張天賦', 'artists_uri': 'spotify:artist:5tRk0bqMQubKAVowp35XtC'}, {'artists_id': '1qW9Pi35NXnu7Q8KWyVYe6', 'artists_name': '陳卓賢 Ian', 'artists_uri': 'spotify:artist:1qW9Pi35NXnu7Q8KWyVYe6'}, {'artists_id': '3wYcmejLVtOoHIq9szUugh', 'artists_name': 'Kaho Hung', 'artists_uri': 'spotify:artist:3wYcmejLVtOoHIq9szUugh'}, {'artists_id': '2QcZxAgcs2I1q7CtCkl6MI', 'artists_name': 'Eason Chan', 'artists_uri': 'spotify:artist:2QcZxAgcs2I1q7CtCkl6MI'}, {'artists_id': '3jS58yKkLzOd8S8IHyCsEm', 'artists_name': 'Panther Chan', 'artists_uri': 'spotify:artist:3jS58yKkLzOd8S8IHyCsEm'}, {'artists_id': '6V1SwiosQqf5XvmoTMCGa9', 'artists_name': 'Dear Jane', 'artists_uri': 'spotify:artist:6V1SwiosQqf
# ...

# %%
song_list = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_uri = row['track']['uri']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    ablum_id = row['track']['album']['id']
    artists_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id': song_id, 'song_name': song_name, 'song_duration': song_duration,
                    'song_popularity': song_popularity, 'song_added': song_added, 'album_id': ablum_id, 'artists_id': artists_id}
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '6UuJk5rvrxSnOAwv6uSr5b',
#   'song_name': '給你幸福 所以幸福',
#   'song_duration': 244693,
#   'song_popularity': 56,
#   'song_added': '2023-11-23T16:00:00Z',
#   'album_id': '2rOeZHhWQCveBEPb3tslYB',
#   'artists_id': '4EXI1ieJe2VDbvNsKOaNQL'},
#  {'song_id': '0xBCMoVEaOfrCqM0bHwPek',
#   'song_name': '後人類的美麗與哀愁',
#   'song_duration': 220216,
#   'song_popularity': 52,
#   'song_added': '2023-11-23T16:00:00Z',
#   'album_id': '2XRiLdbU5VPiLF5jxRPczq',
#   'artists_id': '0UtXMxHMXhwQUI6G6TFDt1'},
#  {'song_id': '4WBNWQZR2TCDanKIg95gpT',
#   'song_name': '救命稻草',
#   'song_duration': 261215,
#   'song_popularity': 55,
#   'song_added': '2023-11-23T16:00:00Z',
#   'album_id': '5OlvQy8lBirp1AiU1ce8u7',
#   'artists_id': '5tRk0bqMQubKAVowp35XtC'},
#  {'song_id': '6UoBjdkU2bnuYqCXFDqME0',
#   'song_name': '夜視鏡',
#   'song_duration': 170400,
#   'song_popularity': 59,
#   'song_added': '2023-11-23T16:00:00Z',
#   'album_id': '0Ht3PakAe4PpudlLLpxmov',
# ...

# %%
album_df = pd.DataFrame.from_dict(song_list)

# %%
album_df
# Out:
#                    song_id                       song_name  song_duration  \
# 0   6UuJk5rvrxSnOAwv6uSr5b                       給你幸福 所以幸福         244693
# 1   0xBCMoVEaOfrCqM0bHwPek                       後人類的美麗與哀愁         220216
# 2   4WBNWQZR2TCDanKIg95gpT                            救命稻草         261215
# 3   6UoBjdkU2bnuYqCXFDqME0                             夜視鏡         170400
# 4   1UdxSRCOnftG6I2dVBkHXH                          只要你不尷尬         243124
# 5   6gj3SEe4x05WfnMjbvviCA  Special One (feat. Eason Chan)         283268
# 6   5LxfxzmlGFCQm8HT93gksZ                         神的不在場證明         272500
# 7   3gOTUuIDMbBYECtnPadsxY                              浮床         213619
# 8   1rPPxVHA0YWiUzxzuFlQDN                              仍在         278670
# 9   6bMgCXapeQEVFgAOr8EvgY                           隱形遊樂場         233187
# 10  2tAHyOEk02Ao7hGMazvaFg                            垃圾女星         211481
# 11  0QA3wOHY0d8IYsevIrBrce                            好好掛住         291588
# ...

# %%
artists_df = pd.DataFrame.from_dict(artists_list)

# %%
artists_df
# Out:
#                 artists_id  artists_name  \
# 0   4EXI1ieJe2VDbvNsKOaNQL      Jay Fung
# 1   0UtXMxHMXhwQUI6G6TFDt1       Gin Lee
# 2   5tRk0bqMQubKAVowp35XtC        MC 張天賦
# 3   1qW9Pi35NXnu7Q8KWyVYe6       陳卓賢 Ian
# 4   3wYcmejLVtOoHIq9szUugh     Kaho Hung
# 5   2QcZxAgcs2I1q7CtCkl6MI    Eason Chan
# 6   3jS58yKkLzOd8S8IHyCsEm  Panther Chan
# 7   6V1SwiosQqf5XvmoTMCGa9     Dear Jane
# 8   1qW9Pi35NXnu7Q8KWyVYe6       陳卓賢 Ian
# 9   2MVfNjocvNrE03cQuxpsWK   Hins Cheung
# 10  0u3m5Sy2zsq4Gk0aduH9s7       Serrini
# 11  5g1lCXhXTqGf2QNpyQXh9S           陳健安
# 12  2G4Ntbg3dYqkUAGrMUZ0U7  Anson Lo 盧瀚霆
# 13  0UtXMxHMXhwQUI6G6TFDt1       Gin Lee
# 14  5tRk0bqMQubKAVowp35XtC        MC 張天賦
# 15  5tRk0bqMQubKAVowp35XtC        MC 張天賦
# 16  1qW9Pi35NXnu7Q8KWyVYe6       陳卓賢 Ian
# 17  5jewGMrZtMNJk5OsZ61Cpo      Edan 呂爵安
# 18  3tvtGR8HzMHDbkLeZrFiBI   Terence Lam
# 19  5tRk0bqMQubKAVowp35XtC        MC 張天賦
# 20  58mVHcSF3eyFFKomq28iRr    Lolly Talk
# 21  5g1lCXhXTqGf2QNpyQXh9S           陳健安
# ...

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                       song_name  song_duration  \
# 0   6UuJk5rvrxSnOAwv6uSr5b                       給你幸福 所以幸福         244693
# 1   0xBCMoVEaOfrCqM0bHwPek                       後人類的美麗與哀愁         220216
# 2   4WBNWQZR2TCDanKIg95gpT                            救命稻草         261215
# 3   6UoBjdkU2bnuYqCXFDqME0                             夜視鏡         170400
# 4   1UdxSRCOnftG6I2dVBkHXH                          只要你不尷尬         243124
# 5   6gj3SEe4x05WfnMjbvviCA  Special One (feat. Eason Chan)         283268
# 6   5LxfxzmlGFCQm8HT93gksZ                         神的不在場證明         272500
# 7   3gOTUuIDMbBYECtnPadsxY                              浮床         213619
# 8   1rPPxVHA0YWiUzxzuFlQDN                              仍在         278670
# 9   6bMgCXapeQEVFgAOr8EvgY                           隱形遊樂場         233187
# 10  2tAHyOEk02Ao7hGMazvaFg                            垃圾女星         211481
# 11  0QA3wOHY0d8IYsevIrBrce                            好好掛住         291588
# ...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.head(5)
# Out:
#                   song_id  song_name  song_duration  song_popularity  \
# 0  6UuJk5rvrxSnOAwv6uSr5b  給你幸福 所以幸福         244693               56
# 1  0xBCMoVEaOfrCqM0bHwPek  後人類的美麗與哀愁         220216               52
# 2  4WBNWQZR2TCDanKIg95gpT       救命稻草         261215               55
# 3  6UoBjdkU2bnuYqCXFDqME0        夜視鏡         170400               59
# 4  1UdxSRCOnftG6I2dVBkHXH     只要你不尷尬         243124               55
#
#              song_added                album_id              artists_id
# 0  2023-11-23T16:00:00Z  2rOeZHhWQCveBEPb3tslYB  4EXI1ieJe2VDbvNsKOaNQL
# 1  2023-11-23T16:00:00Z  2XRiLdbU5VPiLF5jxRPczq  0UtXMxHMXhwQUI6G6TFDt1
# 2  2023-11-23T16:00:00Z  5OlvQy8lBirp1AiU1ce8u7  5tRk0bqMQubKAVowp35XtC
# 3  2023-11-23T16:00:00Z  0Ht3PakAe4PpudlLLpxmov  1qW9Pi35NXnu7Q8KWyVYe6
# 4  2023-11-23T16:00:00Z  0ryBp7G4CRi53am6Hy65IM  3wYcmejLVtOoHIq9szUugh

# %%
artists_df = artists_df.drop_duplicates(subset=['artists_id'])

# %%
artists_df.head(5)
# Out:
#                artists_id artists_name                            artists_uri
# 0  4EXI1ieJe2VDbvNsKOaNQL     Jay Fung  spotify:artist:4EXI1ieJe2VDbvNsKOaNQL
# 1  0UtXMxHMXhwQUI6G6TFDt1      Gin Lee  spotify:artist:0UtXMxHMXhwQUI6G6TFDt1
# 2  5tRk0bqMQubKAVowp35XtC       MC 張天賦  spotify:artist:5tRk0bqMQubKAVowp35XtC
# 3  1qW9Pi35NXnu7Q8KWyVYe6      陳卓賢 Ian  spotify:artist:1qW9Pi35NXnu7Q8KWyVYe6
# 4  3wYcmejLVtOoHIq9szUugh    Kaho Hung  spotify:artist:3wYcmejLVtOoHIq9szUugh

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
song_df.head(5)
# Out:
#                   song_id  song_name  song_duration  song_popularity  \
# 0  6UuJk5rvrxSnOAwv6uSr5b  給你幸福 所以幸福         244693               56
# 1  0xBCMoVEaOfrCqM0bHwPek  後人類的美麗與哀愁         220216               52
# 2  4WBNWQZR2TCDanKIg95gpT       救命稻草         261215               55
# 3  6UoBjdkU2bnuYqCXFDqME0        夜視鏡         170400               59
# 4  1UdxSRCOnftG6I2dVBkHXH     只要你不尷尬         243124               55
#
#              song_added                album_id              artists_id
# 0  2023-11-23T16:00:00Z  2rOeZHhWQCveBEPb3tslYB  4EXI1ieJe2VDbvNsKOaNQL
# 1  2023-11-23T16:00:00Z  2XRiLdbU5VPiLF5jxRPczq  0UtXMxHMXhwQUI6G6TFDt1
# 2  2023-11-23T16:00:00Z  5OlvQy8lBirp1AiU1ce8u7  5tRk0bqMQubKAVowp35XtC
# 3  2023-11-23T16:00:00Z  0Ht3PakAe4PpudlLLpxmov  1qW9Pi35NXnu7Q8KWyVYe6
# 4  2023-11-23T16:00:00Z  0ryBp7G4CRi53am6Hy65IM  3wYcmejLVtOoHIq9szUugh
